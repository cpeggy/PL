# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import jieba
import nltk

# %%
#來源：中時新聞網
url1 = 'https://www.chinatimes.com/opinion/20221010003509-262110?chdtv'
r1 = requests.get(url1)
web_content1 = r1.text
soup1 = BeautifulSoup(web_content1,'lxml')

articleContent1 = soup1.find_all('p')

# 將所有tag p中的text取出並放進list。
article1 = []
for p in articleContent1:
    article1.append(p.text)
    
articleAll1 = '\n'.join(article1)

d1 = articleAll1.replace('[^\w\s]','').replace('／',"").replace('《','').replace('》','').replace('，','').replace('。','').replace('「','').replace('」','').replace('（','').replace('）','').replace('！','').replace('？','').replace('、','').replace('▲','').replace('…','').replace('：','').replace('※以上言論不代表旺中媒體集團立場※','').replace('中時新聞網對留言系統使用者發布的文字圖片或檔案保有片面修改或移除的權利當使用者使用本網站留言服務時表示已詳細閱讀並完全了解且同意配合下述規定','').replace('違反上述規定者中時新聞網有權刪除留言或者直接封鎖帳號請使用者在發言前務必先閱讀留言板規則謝謝配合','')
print(d1)
# Out:
# 回顧1994年4月10日的四一○教改中台灣青年的大學就學率從當時的18%提升到美國的54%以上藉由更廣泛的大學教育培養更多具備思考力判斷力有國際視野的台灣年輕人才然而由於少子化浪潮來襲導致近年來許多學校招生不足而停辦面臨退場的問題教育部退場審議會將7間大學列入專案輔導學校但除了大專院校以外私立高中職也面臨類似的危機
#
#
#
# 根據教育部統計111學年度起大學生數將首次超過高中生未來學生數也將穩定地下滑今年8月12日大學放榜錄取率98.94%缺額學校51所雙雙創下歷年新高其中玄奘大葉明道真理長榮文化等大學的缺額比例均超過9成除了大專院校以外私立高中職也面臨同樣的處境對此教育部表示將會有20所以上的高中職被列為專案輔導學校
#
#
#
# 因應本地學生來源不足而向海外尋求生源成為一個新的方式然而向東南亞及非洲國家尋求生源並不能解決學生人數不足的問題本來大陸學生來台灣留學讀書或交換在一定程度上填補了私立學校生源不足的問題然而因為兩岸關係進入冰封期當前除了已經在台讀書的陸生之外新的大陸學生已然無法來台留學使得私立大學的生源更加雪上加霜私立學校轉型或關閉的速度加快當前共有7所私立大專院校被列入專案輔導學校包含大同技術學院高苑科技大學中州科技大學台灣首府大學明道大學環球科技大學以及和春技術學院
#
# 面臨可能退場的私立學校為了存續比如惇敘工商職業學校傳出台灣法輪大法學會介入由已故學者張清溪教授斥巨資成為惇敘工商的董事長並在 2021 年 10 月 18 日換發法人登記完成姑且不論法輪功介入惇敘工商的校務營運有多深然而地方上已有許多不同的聲音傳出比如法輪功在學校職員學生和家長都不知情的情況下加入學校營運會否影響學生的學習宗教形式的灌輸及宣揚是否對正值成長期的青少年學生帶來思維上的誤導在種種疑問未能獲得釐清之前擬定入學的家長及學生們必須慎而又慎我們也不得不思考以這種方式為學校的存續而接受特殊宗教進入校園是否當前需要警醒
#
# 在台灣少子化時代到來的私校退場潮下如台灣觀光學院大同技術學院亞太創意技術學院台灣首府大學等已然因為招生不足走入歷史教育部在9月召開退場審議會將7間大學列入專案輔導學校教育部長潘文忠國教署長彭富源於10月5日至立法院接受質詢時表示私立高中職則預計將會有20所以上
#
#
#
# ...

# %%
#來源：奇摩新聞
url2 = 'https://tw.stock.yahoo.com/news/%E5%B0%91%E5%AD%90%E5%8C%96%E5%95%8F%E9%A1%8C%E5%9A%B4%E9%87%8D-%E7%A7%81%E6%A0%A1%E6%8E%80%E8%B5%B7%E9%80%80%E5%A0%B4%E6%B5%B7%E5%98%AF-%E4%BB%8A%E5%B9%B4%E5%88%86%E7%99%BC%E7%BC%BA%E9%A1%8D%E5%89%B5%E6%96%B0%E9%AB%98-51%E6%A0%A1%E6%8B%9B%E4%B8%8D%E6%BB%BF-%E9%80%80%E5%A0%B4%E6%A2%9D%E4%BE%8B%E9%80%9A%E9%81%8E-040500856.html'
r2 = requests.get(url2)
web_content2 = r2.text
soup2 = BeautifulSoup(web_content2,'lxml')

articleContent2 = soup2.find_all('p',limit=4)

# 將所有tag p中的text取出並放進list。
article2 = []
for p in articleContent2:
    article2.append(p.text)
    
articleAll2 = '\n'.join(article2)

d2 = articleAll2.replace('[^\w\s]','').replace('／',"").replace('《','').replace('》','').replace('，','').replace('。','').replace('「','').replace('」','').replace('（','').replace('）','').replace('！','').replace('？','').replace('、','').replace('▲','').replace('…','').replace('：','').replace('?','').replace('(','').replace(')','').replace('【','').replace('】','').replace('/','').replace(';','').replace('；','')
print(d2)
# Out:
# 圖表資料來源國家發展委員會中華民國人口推估2022年至2070年2022年8月國家發展委員會
# 實習記者李睿柔新北市111學年大學分發入學受考招改制和少子化衝擊影響今年參與分發學生數大減但許多學校未及時因應調整招生名額分配最終缺額達1萬4千993個錄取率亦創下新高達98.94%僅269人落榜有51所學校未招滿其中連清大臺師大中興大學等頂大也罕見出現缺額今年分發入學名額較去年大減1.1萬人缺額數創新高加上入學人口大幅度下降引起外界關注立法院院會於今年4月22日三讀通過私立高級中等以上學校退場條例加速淘汰不良私校
# 少子化浪潮來襲國家發展委員會表示2022學年度18歲大學入學年齡人口有21.9萬人國委會推估2027年將降至20萬人以下到2070年時僅剩下11.3萬人私校工會也預估118學年逾40所大專院校恐倒閉5年後逾53所私立高中職恐退場
# 根據私立高級中等以上學校退場條例規定學校財務狀況惡化影響校務正常營運或是近一學年度全校50%以上系所等師資質量不符標準將會被教育部列為預警學校如果預警學校在規定改善期限內檢核結果未通過或是三年內被列為預警學校達兩次以上便會被列入專案輔導學校專輔學校兩年內仍未改善教育部應令其於下一學年度停止全部招生並於停止全部招生的當學年度結束時停辦在專輔學校停辦2個月內學校法人應報請教育部核定解散其中三讀條文也規定被列為專案輔導學校2年內可申請改制與其他法人或學校合併或改辦文教社福事業期限內未完成改辦則須退場

# %%
#來源：遠見
url3 = 'https://www.gvm.com.tw/article/95796'
r3 = requests.get(url3)
web_content3 = r3.text
soup3 = BeautifulSoup(web_content3,'lxml')

articleContent3 = soup3.find_all('p',limit=6)

# 將所有tag p中的text取出並放進list。
article3 = []
for p in articleContent3:
    article3.append(p.text)
    
articleAll3 = '\n'.join(article3)

d3 = articleAll3.replace('[^\w\s]','').replace('／',"").replace('《','').replace('》','').replace('，','').replace('。','').replace('「','').replace('」','').replace('（','').replace('）','').replace('！','').replace('？','').replace('、','').replace('▲','').replace('…','').replace('：','').replace('?','').replace('(','').replace(')','').replace('【','').replace('】','').replace('/','').replace(';','').replace('；','').replace('三大絕配組合台式餐點 X 高奢威士忌溫暖人心','').replace('新鮮海產及璀璨夜景 一起來基隆生活吧','')
print(d3)
# Out:
# 私立高級中等以上學校退場條例公告施行後教育部陸續召開私校退場審議會27日下午公布第一波私立高中職專案輔導名單高雄市旗美商工嘉義縣同濟中學入列改善期限為兩年
# 尤榮輝告訴中央社記者上述兩校位處較偏遠都因財務惡化嚴重影響校務運作凸顯私中辦學的困境政府若不拿出作為預估五年內會有大量私中面臨退場危機尤其以新竹苗栗嘉義台南高雄屏東情況最為嚴重不僅衝擊技職人才培育也會擴大城鄉教育資源落差
# 任何一所私校退場都是地方教育資源的重大損失尤榮輝表示少子女化冰河期考驗私校生存能力若放任市場機制自然淘汰必造成偏鄉教育資源失衡期待政府也積極思考提供私校合理辦學空間支持優良私校發展
# 尤榮輝也提到私中聘任不合格教師的情形嚴重也有扣減研究費及導師費狀況呼籲各校提升合格教師率避免欠薪爭議
# 本文轉載自2022.10.28中央社僅反映作者意見不代表本社立場

# %%
#來源：台灣高等教育產業工會
url4 = 'https://www.theunion.org.tw/2021/09/%E3%80%90%E5%A4%A7%E5%AD%B8%E5%BF%AB%E5%A0%B1%E7%AC%AC313%E6%9C%9F%E3%80%91%E7%A7%81%E6%A0%A1%E9%80%80%E5%A0%B4%E6%96%BC%E5%AD%B8%E7%94%9F%E5%8F%88%E6%9C%89%E4%BD%95%E7%9B%8A%EF%BC%9F/'
r4 = requests.get(url4)
web_content4 = r4.text
soup4 = BeautifulSoup(web_content4,'lxml')

articleContent4 = soup4.find_all(["p",'/p'])

# 將所有tag p中的text取出並放進list。
article4 = []
for p in articleContent4:
    article4.append(p.text)
    
articleAll4 = '\n'.join(article4)

d4 = articleAll4.replace('[^\w\s]','').replace('／',"").replace('《','').replace('》','').replace('，','').replace('；','').replace('。','').replace('「','').replace('」','').replace('（','').replace('）','').replace('！','').replace('？','').replace('、','').replace('▲','').replace('…','').replace('：','').replace('?','').replace('(','').replace(')','').replace('【','').replace('】','').replace('/','').replace('台灣高等教育產業工會','').replace('改變高教從加入工會開始','').replace('文謝青龍高教工會大雄分部召集人南華大學通識中心專任教授','').replace('原文取自風傳媒','')
print(d4)
# Out:
# 立法院教育及文化委員會在4月19日2021審查私立高級中等以上學校退場條例草案教育部長潘文忠列席報告並備詢國民黨立委李德維質詢時認為全國六成多的學生在私校若私校退場勢必帶來很嚴重的問題對此潘部長特別強調教育部每年補助學校鼓勵辦學目的是讓學校提出好的教育品質讓學生受益如果學校已經沒有學生不能稱之為學校所以如果學校吸引不了學生入學還勉強維持它的存在這是對不起學生要趕快支持退場條例讓已經沒辦法繼續維持辦學的學校快速退場而非用苟延殘喘的方式影響更多年輕學生的受教權利
#
# 此話一出似乎我們都感受到潘部長對私校學生的關愛之心但這真的是出自部長的肺腑之言嗎如果教育部真的那麼注重學生的受教權那麼過去這二十年來的高教沈淪亂象教育部又在哪裡呢筆者不禁以小人之心度部長之腹大膽地指出或許潘部長的真正重點是在退場條例啊哪裡是真的為學生著想呢
#
# 話說自2017年教育部提出首版私校退場條例但立法院未審議以來私場退場議題就不斷在台灣的各私校裡流傳去年2020教育部再提出新版的私立高級中等以上學校退場條例草案但是這已經是繼國際商業專科學校1990高鳯數位內容學院2014永達技術學院2014中信金融管理學院2015高美醫護管理專科學校2018亞太創意技術學院2019南榮科技大學2019稻江科技暨管理學院2020康寧大學2020等9所大專校院停招之後的事了今年再添台灣觀光學院2021及最近被教育部勒令停招的和春技術學院2021依此趨勢看來恐怕再過幾年就算私校退場條例一直未過大概也不需要了如同輔仁大學戴芬教授在＜私校退場犧牲教師勞動權＞中所言私校退場是一個冗長的教育慢性死亡過程
#
# 當然上述已退場或正在退場的學校有些是看趨勢不佳而自動向教育申請停招有些甚至不顧教育部而自行宣佈停辦有些則是早已無心辦學而被教育部勒令停招以最近的和春科技大學為例它在2015年就被教育部列為專案輔導學校2017年再爆發以百餘位原住民充當人頭學生向教育部詐領上千萬元學雜費補助款經三年來的查核確定這批幽靈學生根本不存在於是教育部於今年2月發函要求和春技術學院110學年起全面停招當然校方需提報停招計畫確保現有688名學生的權益
#
# ...

# %%
#來源：獨立評論
articleAll5= '''私校退場法制化，最終會是堅持公益還是倒向私利？立法院臨時會進入倒數2週，除了重頭戲「111年度中央政府總預算案」，朝野分別提出許多待協商法案，合計高達6,113案，短短幾天自然不可能完成審議，有待朝野協商確定臨時會最後議程。值得教育界注意的是，此次臨時會也將審議《私立高級中等以上學校退場條例》（下稱《退場條例》），草案內容攸關私校退場機制與規範。《退場條例》是否可以順利法制化？又將通過怎樣的內容？值得密切關注。少子女化衍生辦學亂象，私校退場法制化有其必要之所以會有學校退場議題，表面上是少子女化日益嚴峻，但關鍵還是教育市場的供需失衡。如果沒有當年與人口成長率背道而馳的廣設大學政策，就算少子女化使部分學校必須退場，也不至於造成如今尾大不掉的巨大風暴。當前的災難源自1990年代廣設大學、並將技職院校升格為科技大學的政策。在高教擴充政策下，2007年（96學年度）全國大專院校數量達到驚人的164間，但台灣每年出生的嬰兒數量卻從1980年代的40萬人高峰降至2021年的15萬3千餘人，直接衝擊各級學校招生與辦學。首當其衝的，其實是國民中小學。根據教育部統計，各縣市國民小學校數已從99學年度的2,661校下降至109學年度的2,631校，扣除新設學校不計，10年來停辦或整併的國民中小學數量不少。另依教育部長提供給立法院的報告，大學一年級學生人數將於117年降為16萬2千人，相較於101年減少約11萬6千人，減少幅度高達4成，高教退場海嘯即將襲來。少子女化已對台灣學校教育形成一個系統性的風暴。在生源嚴重減少下，部分私校出現嚴重財務危機，發生各種招生與辦學亂象，進而影響教育品質與師生權益，更有甚者，還出現不少掏空校產、董事會介入學校經營的弊案。而以上這些亂象又環環相扣，形成難以根本解決的惡性循環。為規範公立國中小退場事宜，教育部根據《國民教育法》第4-1條授權訂定了《公立國民小學及國民中學合併或停辦準則》，並自2017年1月起施行，各縣市對公立國中小退場的處理漸上軌道。相較於此，早在2013年9月教育部就已提出私立大學退場機制，但由於種種原因，迄今未能完成法制化。私校退場應堅持公共化底線辦學不佳的私校必須退場，已是社會共識，問題出在退場機制與退場後校產如何處置，這也是《退場條例》在第9屆國會未能完成法制化、與此前教育文化委員會對爭議條文並無共識的關鍵。各界的疑慮則是，《退場條例》固然重要，但以臨時會朝野協商方式處理如此重要之法案，是否有可能淪為各取所需與利益交換，進而合法圖利私人？私校退場攸關社會公義與師生權益，朝野委員應為全民公產把關，確保《退場條例》回歸公共化精神，讓國家挹注到私校的公共資源與資產，在退場後真正回到公共教育領域。為避免「校產歸私」或私相授受，私校退場剩餘校產的歸屬對象，除原規劃的中央或地方政府、私校退場基金、公立學校外，不宜再追加其他；此外，針對私校退場是否保有「逃逸路線」的問題，建議已列入專案輔導的學校不得改制、改辦、合併，以避免即將倒閉的私校還有機會假借辦中小學來規避退場，或藉「私私併」讓私校董事會有空間私相授受、規避校產歸公。私校退場早已是現在進行式，此前不少退場衍生爭議，近日終於出現正向案例。已於去年9月起停辦的台灣觀光學院董事會就公開徵求中央機關、花蓮縣政府、公立大專校院運用校地及建物計畫，最終董事會決議將校產捐贈給國立空中大學，空大則計畫把這塊地規劃為創生產業園區，提供終身學習機會，成為國內私校校產轉讓給公立學校的首例。這證明私校退場後校產歸公，不僅符合公益，也確實可行。《私校退場條例》闖關在即，最後的結果會是堅持公益還是傾向私利？攸關高教百年大計與鉅額金錢利益的公共校產歸屬，呼籲朝野委員堅守公共化底線，莫讓私人利益凌駕於公共利益之上。'''

d5 = articleAll5.replace('[^\w\s]','').replace('／',"").replace('《','').replace('》','').replace('，','').replace('；','').replace('。','').replace('「','').replace('」','').replace('（','').replace('）','').replace(',','').replace('！','').replace('？','').replace('、','').replace('▲','').replace('…','').replace('：','').replace('?','').replace('(','').replace(')','').replace('【','').replace('】','').replace('/','').replace('台灣高等教育產業工會','').replace('改變高教從加入工會開始','').replace('文謝青龍高教工會大雄分部召集人南華大學通識中心專任教授','').replace('原文取自風傳媒','')
print(d5)
# Out:
# 私校退場法制化最終會是堅持公益還是倒向私利立法院臨時會進入倒數2週除了重頭戲111年度中央政府總預算案朝野分別提出許多待協商法案合計高達6113案短短幾天自然不可能完成審議有待朝野協商確定臨時會最後議程值得教育界注意的是此次臨時會也將審議私立高級中等以上學校退場條例下稱退場條例草案內容攸關私校退場機制與規範退場條例是否可以順利法制化又將通過怎樣的內容值得密切關注少子女化衍生辦學亂象私校退場法制化有其必要之所以會有學校退場議題表面上是少子女化日益嚴峻但關鍵還是教育市場的供需失衡如果沒有當年與人口成長率背道而馳的廣設大學政策就算少子女化使部分學校必須退場也不至於造成如今尾大不掉的巨大風暴當前的災難源自1990年代廣設大學並將技職院校升格為科技大學的政策在高教擴充政策下2007年96學年度全國大專院校數量達到驚人的164間但台灣每年出生的嬰兒數量卻從1980年代的40萬人高峰降至2021年的15萬3千餘人直接衝擊各級學校招生與辦學首當其衝的其實是國民中小學根據教育部統計各縣市國民小學校數已從99學年度的2661校下降至109學年度的2631校扣除新設學校不計10年來停辦或整併的國民中小學數量不少另依教育部長提供給立法院的報告大學一年級學生人數將於117年降為16萬2千人相較於101年減少約11萬6千人減少幅度高達4成高教退場海嘯即將襲來少子女化已對台灣學校教育形成一個系統性的風暴在生源嚴重減少下部分私校出現嚴重財務危機發生各種招生與辦學亂象進而影響教育品質與師生權益更有甚者還出現不少掏空校產董事會介入學校經營的弊案而以上這些亂象又環環相扣形成難以根本解決的惡性循環為規範公立國中小退場事宜教育部根據國民教育法第4-1條授權訂定了公立國民小學及國民中學合併或停辦準則並自2017年1月起施行各縣市對公立國中小退場的處理漸上軌道相較於此早在2013年9月教育部就已提出私立大學退場機制但由於種種原因迄今未能完成法制化私校退場應堅持公共化底線辦學不佳的私校必須退場已是社會共識問題出在退場機制與退場後校產如何處置這也是退場條例在第9屆國會未能完成法制化與此前教育文化委員會對爭議條文並無共識的關鍵各界的疑慮則是退場條例固然重要但以臨時會朝野協商方式處理如此重要之法案是否有可能淪為各取所需與利益交換進而合法圖利私人私校退場攸關社會公義與師生權益朝野委員應為全民公產把關確保退場條例回歸公
# ...

# %%
#來源：讀+
url6 = 'https://www.readr.tw/post/2913'
r6 = requests.get(url6)
web_content6 = r6.text
soup6 = BeautifulSoup(web_content6,'lxml')

articleContent6 = soup6.find_all("p",class_="g-article-paragraph")

# 將所有tag p中的text取出並放進list。
article6 = []
for p in articleContent6:
    article6.append(p.text)
    
articleAll6 = '\n'.join(article6)

d6 = articleAll6.replace('[^\w\s]','').replace('／',"").replace('《','').replace('》','').replace('，','').replace('；','').replace('。','').replace('「','').replace('」','').replace('（','').replace('）','').replace('！','').replace('？','').replace('、','').replace('▲','').replace('…','').replace('：','').replace('?','').replace('(','').replace(')','').replace('【','').replace('】','').replace('/','').replace('-','').replace('20220826 更新華梵大學回應於原文章20220906 新增台灣首府大學回應','').replace('r','').replace('註READr 就報導中提到的學校逐一邀訪將回應及結果一併呈現如下','')
print(d6)
type(d6)
# Out:
# 才剛進入台灣首府大學休閒管理所就讀陳建良想都沒想過不到 3 個月後自己可能就得轉學
# 5 月 17 日一大早他和同學正在準備稍晚的年度學術研討會突然間校長張淑中走進會議室請所有人先到教室外簽名報到表示要臨時舉辦說明會
# 在場的學生一頭霧水張淑中接著說各位同學學校決定這學期結束後就停辦我們會開始後續的安置作業你們也可以想想未來要去哪裡
# 沒看到學校擬停辦的公告不清楚轉介的配套措施現場甚至沒有任何的大學部學生錯愕的陳建良向校長提問那我們該怎麼辦
# 教育部會想辦法我們已經和教育部有默契了張淑中回答得簡潔有力
# 陳建良後來才知道教育部根本沒收到台首大的停辦申請計畫書校長當時承諾的配套方案也全都不可能實現後來成為自救會學生代表的陳建良語帶無奈今天一間學校要退場機制是不是應該更周全一點不要急著一刀砍給學生造成困擾
# 張淑中對此回應5 月 17 日的說明會舉辦的匆忙是因為她前一天早上才從董事會確定全面停辦的結論基於想盡快與學生溝通事前通知的時間和簽到的方式才出現落差會議中已和學生解釋
# 至於學生提及校方溝通與安置方式草率張淑中表示可以理解學生突然聽聞停招停辦的消息會有情緒但她並未說出自己想想未來要去哪等言論當時聽聞董事會的決議她的心情也是震驚且沉重但作為董事會政策的執行者校長能做的事情並不是改變學校停辦的命運而是盡可能為學生向教育部爭取到更好的安置條件
# 舉例來說她在 5 月 23 日發表一封公開信給全校學生指出其了解同學對於學校停辦的不滿雖然上任只有3個多月仍會努力解決問題並提出原校上課他校畢業的構想如果台灣首府大學停辦希望幫助學生盡量在原校上課但取得鄰近私立大學的畢業證書
# 即使台首大學生自救會發起遊行抗議希望爭取原校畢業教育部仍以無法確保教學品質為由拍板臺南市台灣首府大學 111 學年度全面停招7 月底將協助學生轉學包含 33 名已完成報到的研究所新生從 4 月傳出停招風聲6 月遭列專案輔導學校到 7 月確定各學制停止招生台灣首府大學的退場程序可說是飆速進行
# 除了台灣首府大學宜蘭縣蘭陽技術學院今年也確定停辦新北市華夏科技大學南投縣南開科技大學則陸續傳出要把校地捐贈給公立學校的消息後來都因意見分歧而暫時喊停私立大專校院在這個學期突然湧現跳船潮試圖加速離開高教體系原因和今年 4 月立法院三讀通過的私立高級中等以上學校退場條例關係密切
# ...

# %%
d=d1+d2+d3+d4+d5+d6
print(d)
type(d)
# Out:
# 回顧1994年4月10日的四一○教改中台灣青年的大學就學率從當時的18%提升到美國的54%以上藉由更廣泛的大學教育培養更多具備思考力判斷力有國際視野的台灣年輕人才然而由於少子化浪潮來襲導致近年來許多學校招生不足而停辦面臨退場的問題教育部退場審議會將7間大學列入專案輔導學校但除了大專院校以外私立高中職也面臨類似的危機
#
#
#
# 根據教育部統計111學年度起大學生數將首次超過高中生未來學生數也將穩定地下滑今年8月12日大學放榜錄取率98.94%缺額學校51所雙雙創下歷年新高其中玄奘大葉明道真理長榮文化等大學的缺額比例均超過9成除了大專院校以外私立高中職也面臨同樣的處境對此教育部表示將會有20所以上的高中職被列為專案輔導學校
#
#
#
# 因應本地學生來源不足而向海外尋求生源成為一個新的方式然而向東南亞及非洲國家尋求生源並不能解決學生人數不足的問題本來大陸學生來台灣留學讀書或交換在一定程度上填補了私立學校生源不足的問題然而因為兩岸關係進入冰封期當前除了已經在台讀書的陸生之外新的大陸學生已然無法來台留學使得私立大學的生源更加雪上加霜私立學校轉型或關閉的速度加快當前共有7所私立大專院校被列入專案輔導學校包含大同技術學院高苑科技大學中州科技大學台灣首府大學明道大學環球科技大學以及和春技術學院
#
# 面臨可能退場的私立學校為了存續比如惇敘工商職業學校傳出台灣法輪大法學會介入由已故學者張清溪教授斥巨資成為惇敘工商的董事長並在 2021 年 10 月 18 日換發法人登記完成姑且不論法輪功介入惇敘工商的校務營運有多深然而地方上已有許多不同的聲音傳出比如法輪功在學校職員學生和家長都不知情的情況下加入學校營運會否影響學生的學習宗教形式的灌輸及宣揚是否對正值成長期的青少年學生帶來思維上的誤導在種種疑問未能獲得釐清之前擬定入學的家長及學生們必須慎而又慎我們也不得不思考以這種方式為學校的存續而接受特殊宗教進入校園是否當前需要警醒
#
# 在台灣少子化時代到來的私校退場潮下如台灣觀光學院大同技術學院亞太創意技術學院台灣首府大學等已然因為招生不足走入歷史教育部在9月召開退場審議會將7間大學列入專案輔導學校教育部長潘文忠國教署長彭富源於10月5日至立法院接受質詢時表示私立高中職則預計將會有20所以上
#
#
#
# ...

# %%
jieba.load_userdict('text.txt') # 輸入自己字典的路徑

# %%
# 設定停用字詞 
stopwords = {}.fromkeys(["如果","可以","也","但","來","個","再","在","的","和","是","有","更","會","可能","有何","從","對","就", '\n','越','為','我們','這種','多','越來',' ','停招','停辦','了','後','有些','或','讓','與','已','於','還是','堅持','1','2','3','4','5','6','7','8','9','0','他','她','個','十','百','千','萬','除了','之外','年','月','日','10','2022','然而','到', '上','下','左','右','左右','而','及','以外','會將','是否','2070','以上','以下','內','外','被','等','尤榮輝','27','都','若','及','上午','下午','嗎','呢','所','之','不','這些','就是','真的','\xa0'])

# %%
# 使用cut_for_search(搜尋引擎)斷詞模式並產生字詞頻率的dictionary (並剔除stopwords的計算)
Sentence1 = jieba.cut_for_search(d)

# %%
jieba.setLogLevel(20)

Sentence = jieba.cut(d, cut_all=True)
print('全模式'+": "  + "/ ".join(Sentence) + '\n')   
 
Sentence = jieba.cut(d, cut_all=False)
print('精確模式'+": " + "/ ".join(Sentence)+ '\n')  
 
Sentence = jieba.cut(d)  
print('Default為精確模式'+": " + "/ ".join(Sentence)+ '\n')
 
Sentence = jieba.cut_for_search(d)  
print('搜索引擎模式'+": " + "/ ".join(Sentence)+ '\n')
# Out:
# 全模式: /
# / /
# / /
# / /
# / / 回/ 顧/ 1994/ 年/ 4/ 月/ 10/ 日/ 的/ 四/ 一/ ○/ 教改/ 中台/ 灣/ 青年/ 的/ 大學/ 就/ 學/ 率/ 從/ 當/ 時/ 的/ 18/ %/ 提升/ 升到/ 美/ 國/ 的/ 54/ %/ 以上/ 藉由/ 更/ 廣/ 泛/ 的/ 大學/ 教育/ 培/ 養/ 更多/ 多具/ 具備/ 思考/ 思考力/ 判/ 斷/ 力/ 有/ 國/ 際/ 視/ 野/ 的/ 台/ 灣/ 年輕/ 人才/ 然而/ 由於/ 少子/ 少子化/ 子化/ 浪潮/ 來/ 襲/ 導致/ 近年/ 來/ 許/ 多/ 學/ 校/ 招生/ 不足/ 而/ 停/ 辦/ 面臨/ 退場/ 的/ 問/ 題/ 教育/ 教育部/ 退場/ 審議/ 會/ 將/ 7/ 間/ 大學/ 列入/ 專案輔導/ 專案輔導學校/ 但/ 除了/ 大專院校/ 院校/ 以外/ 私立/ 私立高中/ 私立高中職/ 高中/ 職/ 也/ 面臨/ 類似/ 類似的/ 似的/ 危/ 機/ /
# / /
# / /
# / /
# / / 根/ 據/ 教育/ 教育部/ 統/ 計/ 111/ 學年度/ 年度/ 起/ 大學/ 學生/ 學生數/ 將/ 首次/ 超/ 過/ 高中/ 高中生/ 中生/ 未/ 來/ 學生/ 學生數/ 也/ 將/ 穩定地/ 地下/ 下滑/ 今年/ 8/ 月/ 12/ 日/ 大學/ 大學放榜/ 放榜/ 錄取率/ 98/ ./ 94/ %/ 缺/ 額/ 學/ 校/ 51/ 所/ 雙雙/ 創/ 下/ 歷/ 年/ 新高/ 其中/ 玄奘/ 大葉/ 明道/ 真理/ 長榮/ 文化/ 等/ 大學/ 的/ 缺/ 額/ 比例/ 均/ 超/ 過/ 9成/ 除了/ 大專院校/ 院校/ 以外/ 私立/ 私立高中/ 私立高中職/ 高中/ 職/ 也/ 面臨/ 同/ 樣/ 的/ 處/ 境/ 對/ 此/ 教育/ 教育部/ 表示/ 將/ 會/ 有/ 20/ 所以/ 以上/ 的/ 高中/ 職/ 被/ 列/ 為/ 專案輔導/ 專案輔導學校/ /
# / /
# / /
# / /
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# 文字雲樣式設定
wc = WordCloud(font_path="C:/Windows/Fonts/msjh.ttc", #設置字體
               background_color="white", #背景顏色
               max_words = 20 ,        #文字雲顯示最大詞數
               stopwords=stopwords)

# %%
# create a python dictionary
hash = {}
for item in Sentence1:

    if item in stopwords:
        continue
    
    if item in hash:
        hash[item] += 1
    else:
        hash[item] = 1

# %%
hash
# Out:
# {'回顧': 2,
#  '1994': 1,
#  '四': 1,
#  '一': 4,
#  '○': 1,
#  '教改': 1,
#  '中台': 1,
#  '中台灣': 1,
#  '青年': 1,
#  '大學': 96,
#  '學率': 1,
#  '當時': 6,
#  '18%': 1,
#  '提升': 3,
#  '美國': 1,
#  '54%': 1,
#  '藉由': 1,
#  '更廣泛': 1,
#  '教育': 93,
#  '培養': 1,
#  '具備': 1,
#  '思考': 3,
#  '思考力': 1,
#  '判斷力': 1,
#  '國際視野': 1,
#  '台灣': 12,
#  '年輕': 2,
#  '人才': 2,
#  '由於': 2,
#  '少子': 12,
#  '子化': 7,
#  '少子化': 7,
#  '浪潮': 2,
#  '來襲': 2,
#  '導致': 2,
#  '近年': 2,
#  '許多學校': 2,
#  '招生': 18,
#  '不足': 13,
#  '面臨': 13,
#  '退場': 102,
#  '問題': 17,
#  '教育部': 66,
#  '審議': 7,
#  '間': 5,
#  '列入': 8,
#  '專案輔導學校': 11,
#  '院校': 8,
#  '大專院校': 7,
#  '私立': 37,
#  '高中': 9,
#  '私立高中職': 5,
#  '類似': 3,
#  '似的': 2,
#  '類似的': 2,
#  '危機': 6,
#  '根據': 4,
#  '統計': 2,
#  '111': 6,
#  '年度': 19,
#  '學年度': 17,
#  '起大': 1,
#  '學生': 121,
#  '學生數': 9,
#  '將': 2,
#  '首次': 1,
#  '超過': 8,
#  '中生': 3,
#  '高中生': 3,
#  '未來': 7,
#  '也將': 2,
#  '穩定地': 1,
#  '下滑': 1,
#  '今年': 9,
#  '12': 3,
#  '放榜': 1,
#  '大學放榜': 1,
#  '錄取率': 2,
#  '98.94%': 2,
# ...

# %%
# 使用dictionary的內容產生文字雲
wc.generate_from_frequencies(hash)

# %%
# 視覺化呈現
plt.imshow(wc)
plt.axis("off")
plt.figure(figsize=(40,20), dpi =1600)
plt.show()

# %%
wc.to_file('outputbyallnews.png')

# %%
import pandas as pd

# %%
articlesum1 = pd.read_csv('中時新聞網output詞表.csv', index_col = 0)

articlesum1
# Out:
#         詞頻
# 大學      16
# 學生      11
# 私立      11
# 學校       9
# 教育       7
# 教育部      6
# 高中       5
# 退場       5
# 不足       5
# 專案輔導學校   4
# 問題       4
# 面臨       4
# 存續       4
# 惇敘       4
# 工商       4
# 科技       4
# 生源       4
# 進入       3
# 接受       3
# 私立高中職    3
# 財務       3
# 宗教       3
# 列入       3
# 台灣       3
# 惇敘工商     3
# 院校       3
# 大專院校     3
# 當前       3
# 學生數      3
# 20       2
# 將會       2
# 大同技術學院   2
# 大同       2
# 表示       2
# 新        2

# %%
articlesum2 = pd.read_csv('奇摩新聞output詞表.csv', index_col = 0)
articlesum2
# Out:
#          詞頻
# 學校        8
# 退場        4
# 學年度       4
# 年度        4
# 招生        3
# 私立        3
# 今年        3
# 達         3
# 分發        3
# 大學        3
# 缺額        3
# 規定        3
# 未         3
# 預警        3
# 列為        3
# 教育部       3
# 人口        3
# 教育        3
# 國家發展委員會   3
# 新高        2
# 全部        2
# 停止        2
# 中等        2
# 退場條例      2
# 專輔        2
# 專案輔導學校    2
# 法人        2
# 高級        2
# 三讀        2
# 或是        2
# 期限        2
# 改善        2
# 名額        2
# 其中        2
# 分發入學      2

# %%
articlesum3 = pd.read_csv('遠見output詞表.csv', index_col = 0)
articlesum3
# Out:
#       詞頻
# 私校     5
# 退場     4
# 教育     4
# 資源     3
# 私中     3
# 私立     2
# 辦學     2
# 政府     2
# 不      2
# 合格     2
# 合格教師   2
# 城鄉     1
# 衝擊     1
# 生存能力   1
# 能力     1
# 生存     1
# 考驗     1
# 冰河期    1
# 冰河     1
# 少子女化   1
# 子女     1
# 少子     1
# 不僅     1
# 表示     1
# 擴大     1
# 人才     1
# 技職人才   1
# 損失     1
# 培育     1
# 市場機制   1
# 重大     1
# 地方     1
# 一所     1
# 任何     1
# 落差     1

# %%
articlesum4 = pd.read_csv('台灣高等教育產業工會output詞表.csv', index_col = 0)
articlesum4
# Out:
#       詞頻
# 學生    65
# 教育    29
# 退場    27
# 大學    26
# 學校    24
# 私校    20
# 教育部   18
# 社團    12
# 退場條例  10
# 學習    10
# 受教權   10
# 受教    10
# 權益     9
# 課程     8
# 各      8
# 老師     8
# 活動     8
# 台灣     7
# 把      7
# 說      7
# 畢業     7
# 稻江     7
# 教師     7
# 潘部長    7
# 一個     6
# 甚至     6
# 目前     6
# 工作     6
# 計畫     6
# 一些     5
# 當然     5
# 管理     5
# 董事     5
# 辦學     5
# 他們     5

# %%
articlesum5 = pd.read_csv('獨立評論output詞表.csv', index_col = 0)
articlesum5
# Out:
#       詞頻
# 退場    29
# 私校    16
# 教育    11
# 校產     9
# 學校     9
# 公共     7
# 退場條例   7
# 大學     6
# 公立     6
# 法制     5
# 法制化    5
# 朝野     5
# 中小     5
# 年度     4
# 併      4
# 教育部    4
# 利益     4
# 董事     4
# 少子     4
# 子女     4
# 少子女化   4
# 攸關     3
# 減少     3
# 學年度    3
# 國民     3
# 高教     3
# 校      3
# 政策     3
# 完成     3
# 機制     3
# 不少     3
# 公益     3
# 中央     3
# 政府     3
# 協商     3

# %%
articlesum6 = pd.read_csv('讀+output詞表.csv', index_col = 0)
articlesum6
# Out:
#         詞頻
# 大學      16
# 學生      11
# 私立      11
# 學校       9
# 教育       7
# 教育部      6
# 高中       5
# 退場       5
# 不足       5
# 專案輔導學校   4
# 問題       4
# 面臨       4
# 存續       4
# 惇敘       4
# 工商       4
# 科技       4
# 生源       4
# 進入       3
# 接受       3
# 私立高中職    3
# 財務       3
# 宗教       3
# 列入       3
# 台灣       3
# 惇敘工商     3
# 院校       3
# 大專院校     3
# 當前       3
# 學生數      3
# 20       2
# 將會       2
# 大同技術學院   2
# 大同       2
# 表示       2
# 新        2
