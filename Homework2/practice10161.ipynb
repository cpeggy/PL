# %%
#分析問卷and找出理想訪談者

# %%
import json
MuseumE=open('jsoncrack (7).json',encoding="UTF-8")

# %%
reply = json.load(MuseumE)
for n in reply.items():
    print(n)
# Out:
# ('replytoMOCA', {'不願意接受訪談': {'對當代藝術館的第一印象分數': {'1': [], '2': [], '3': [{'性別': '生理女', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '陳璇', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 參加館內活動, 獨自參觀', '簡單與我們分享讓你印象深刻的博物館服務': '奇美博物館有小車車可以從停車場到博物館接送', '您過去參觀「台北當代藝術館」的次數': 2, '滿意度': [{'[導覽服務]': 3, '[館內標示]': 3, '[空間規劃]': 3, '[顧客服務]': 3, '[周邊景點]': 4}]}, {'性別': '生理男', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '姚貫升', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館', '看展的喜好方式（可複選）': '租借導覽機, 走馬看花隨性看, 聽導覽員解說, 自己閱讀手冊或說明牌, 參加館內活動', '簡單與我們分享讓你印象深刻的博物館服務': '好像都還好', '您過去參觀「台北當代藝術館」的次數': 0, '滿意度': []}, {'性別': '生理男', '年齡': '19-25歲', '族群': '未婚，非學生身份', '姓名': '周橘皮', '最近2年參觀博物館的頻率': '每個月1-3次', '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立臺灣歷史博物館, 國父紀念館, 國立台灣美術館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 獨自參觀', '簡單與我們分享讓你印象深刻的博物館服務': '那時候腳受傷，北美館
# ...

# %%
data=reply.get('replytoMOCA')

# %%
data.items()
# Out:
# dict_items([('不願意接受訪談', {'對當代藝術館的第一印象分數': {'1': [], '2': [], '3': [{'性別': '生理女', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '陳璇', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 參加館內活動, 獨自參觀', '簡單與我們分享讓你印象深刻的博物館服務': '奇美博物館有小車車可以從停車場到博物館接送', '您過去參觀「台北當代藝術館」的次數': 2, '滿意度': [{'[導覽服務]': 3, '[館內標示]': 3, '[空間規劃]': 3, '[顧客服務]': 3, '[周邊景點]': 4}]}, {'性別': '生理男', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '姚貫升', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館', '看展的喜好方式（可複選）': '租借導覽機, 走馬看花隨性看, 聽導覽員解說, 自己閱讀手冊或說明牌, 參加館內活動', '簡單與我們分享讓你印象深刻的博物館服務': '好像都還好', '您過去參觀「台北當代藝術館」的次數': 0, '滿意度': []}, {'性別': '生理男', '年齡': '19-25歲', '族群': '未婚，非學生身份', '姓名': '周橘皮', '最近2年參觀博物館的頻率': '每個月1-3次', '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立臺灣歷史博物館, 國父紀念館, 國立台灣美術館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 獨自參觀', '簡單與我們分享讓你印象深刻的博物館服務': '那時候腳受傷，北美館的服務人
# ...

# %%
#check the item's type
type(data)
# Out:
# dict

# %%
###ㄟㄉㄡ我想比較慢所以分解成一長串動作找出問卷回覆數量QQ

# %%
####找出願意訪談問卷數量

# %%
aY=data['願意接受訪談']
#check the item's type
type(aY)
# Out:
# dict

# %%
bY=aY['對當代藝術館的第一印象分數']
#check the item's type
type(bY)
# Out:
# dict

# %%
bY['1']
# Out:
# []

# %%
bY['2']
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '陳玉書🍿️',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 嘉義文化創意產業園區, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 樹火紀念紙博物館',
#   '看展的喜好方式（可複選）': '租借導覽機, 聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 一定要打卡, 參加館內活動',
#   '簡單與我們分享讓你印象深刻的博物館服務': '用linebot 做成的語音導覽服務',
#   '您過去參觀「台北當代藝術館」的次數': 3,
#   '滿意度': [{'[導覽服務]': 5,
#     '[館內標示]': 4,
#     '[空間規劃]': 3,
#     '[顧客服務]': 3,
#     '[周邊景點]': 4,
#     '簡單與我們分享對 「台北當代藝術館」印象深刻的體驗': '展場內有很多互動裝置，可以跟觀者產生較大的連結'}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '陳姿伶',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '租借導覽機, 走馬看花隨性看, 會跟著排隊參與體驗, 聽導覽員解說, 和朋友邊看邊討論, 一定要拍照, 一定要打卡, 購買紀念品, 一定會蓋紀念章, 參加館內活動, 獨自參觀',
#   '簡單與我們分享讓你印象深刻的博物館服務': '拍貼機 互動裝置 漂亮的光',
#   '您過去參觀「台北當代藝術館」的次數': 2,
#   '滿意度': [{'[導覽服務]': 4,
#     '[館內標示]': 2,
# ...

# %%
bY['3']
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '🐯',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看',
#   '簡單與我們分享讓你印象深刻的博物館服務': '高中畢業旅行去故宮南院，裡面展示的文物很多 導覽講的很仔細，各種擺飾也很漂亮。',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []},
#  {'性別': '生理男',
#   '年齡': '18歲以下',
#   '族群': '未婚，學生身份',
#   '姓名': '萊恩',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '台中科博館…？',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 一定要拍照',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '蘇文慈',
#   '最近2年參觀博物館的頻率': '每個月1-3次',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照',
#   '您過去參觀「台北當代藝術館」的次數': 2,
#   '滿意度': [{'[導覽服務]': 2, '[館內標示]': 2, '[空間規劃]': 3, '[顧客服務]': 3, '[周邊景點]': 4}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '黃千華',
# ...

# %%
bY['4']
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '劉依蘋',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國父紀念館, 國立台灣美術館, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 購買紀念品',
#   '簡單與我們分享讓你印象深刻的博物館服務': '有一些互動活動 例如投票之類的',
#   '您過去參觀「台北當代藝術館」的次數': 1,
#   '滿意度': [{'[導覽服務]': 4, '[館內標示]': 4, '[空間規劃]': 4, '[顧客服務]': 4, '[周邊景點]': 4}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '哈納',
#   '最近2年參觀博物館的頻率': '每個月1-3次',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國立台灣美術館, 嘉義文化創意產業園區, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 樹火紀念紙博物館',
#   '看展的喜好方式（可複選）': '會跟著排隊參與體驗, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 獨自參觀',
#   '簡單與我們分享讓你印象深刻的博物館服務': '有良好ㄉ動線引導會很加分！',
#   '您過去參觀「台北當代藝術館」的次數': 3,
#   '滿意度': [{'[導覽服務]': 4,
#     '[館內標示]': 4,
#     '[空間規劃]': 4,
#     '[顧客服務]': 4,
#     '[周邊景點]': 5,
#     '簡單與我們分享對 「台北當代藝術館」印象深刻的體驗': '門票非常用心！票真ㄉ好便宜'}]},
#  {'性別': '生理男',
#   '年齡': '19-25歲',
# ...

# %%
bY['5']
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '咪',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間': '國立故宮博物院, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 世界宗教博物館、國立台灣科學教育館',
#   '看展的喜好方式': '走馬看花隨性看, 聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論',
#   '簡單與我們分享讓你印象深刻的博物館服務': '上次去了宗教博物館 平常對宗教的事不太會去觸碰 本身不信教 但因為朋友邀約就一起去了 我們是要去博物館內的特展 但由於外面的導覽員實在太熱情 就被拉去很多地方聽了很多關於宗教的解說 其實還蠻有趣的 裡面有各種宗教代表性的建築和物品、經文等等 在特展中也是沈浸式的體驗了生死輪迴 很有趣！是值得去嘗試的體驗！',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': [{}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': 'Stacy',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間': '臺北當代藝術館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 獨自參觀',
#   '簡單與我們分享讓你印象深刻的博物館服務': '無',
#   '您過去參觀「台北當代藝術館」的次數': 4,
#   '滿意度': [{'[導覽服務]': 4, '[館內標示]': 4, '[空間規劃]': 4, '[顧客服務]': 4, '[周邊景點]': 4}]}]

# %%
#bY['1'] is empty list, so we donot put into calculate
cY=len(bY['2'])+len(bY['3'])+len(bY['4'])+len(bY['5'])
cY
# Out:
# 14

# %%
####找出不願意訪談問卷數量

# %%
aN=data['不願意接受訪談']
#check the item's type
type(aN)
# Out:
# dict

# %%
bN=aN['對當代藝術館的第一印象分數']
#check the item's type
type(bN)
# Out:
# dict

# %%
bN['1']
# Out:
# []

# %%
bN['2']
# Out:
# []

# %%
bN['3']
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '陳璇',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 參加館內活動, 獨自參觀',
#   '簡單與我們分享讓你印象深刻的博物館服務': '奇美博物館有小車車可以從停車場到博物館接送',
#   '您過去參觀「台北當代藝術館」的次數': 2,
#   '滿意度': [{'[導覽服務]': 3, '[館內標示]': 3, '[空間規劃]': 3, '[顧客服務]': 3, '[周邊景點]': 4}]},
#  {'性別': '生理男',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '姚貫升',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館',
#   '看展的喜好方式（可複選）': '租借導覽機, 走馬看花隨性看, 聽導覽員解說, 自己閱讀手冊或說明牌, 參加館內活動',
#   '簡單與我們分享讓你印象深刻的博物館服務': '好像都還好',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []},
#  {'性別': '生理男',
#   '年齡': '19-25歲',
#   '族群': '未婚，非學生身份',
#   '姓名': '周橘皮',
#   '最近2年參觀博物館的頻率': '每個月1-3次',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立臺灣歷史博物館, 國父紀念館, 國立台灣美術館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 獨自參觀',
# ...

# %%
bN['4']
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '藍',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '租借導覽機, 和朋友邊看邊討論, 購買紀念品, 獨自參觀',
#   '簡單與我們分享讓你印象深刻的博物館服務': '幫作品用了AR 的效果但看起來有點怪？',
#   '您過去參觀「台北當代藝術館」的次數': 2,
#   '滿意度': [{'[導覽服務]': 4,
#     '[館內標示]': 5,
#     '[空間規劃]': 4,
#     '[顧客服務]': 4,
#     '[周邊景點]': 3,
#     '簡單與我們分享對 「台北當代藝術館」印象深刻的體驗': '票券很可愛，販售票的人會提供當天展覽資訊'}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '小李',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間（可複選）': '奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 國立台灣美術館, 嘉義文化創意產業園區, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 水里蛇窯',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 同一個展去很多次, 會跟著排隊參與體驗, 聽導覽員解說, 自己閱讀手冊或說明牌, 一定要拍照, 獨自參觀',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '洪',
#   '最近2年參觀博物館的頻率': '每個月1-3次',
# ...

# %%
bN['5']
# Out:
# [{'性別': '生理男',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '李冠煒',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國父紀念館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 參加館內活動, 獨自參觀',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []}]

# %%
#bN['1'] and bN['2'] are empty lists, so we donot put into calculate
cN=len(bN['3'])+len(bN['4'])+len(bN['5'])
cN
# Out:
# 13

# %%
print("總共回覆的數量：",cY+cN)
print("願意接受訪談人數：",cY)
print("不願意接受訪談人數：",cN)
# Out:
# 總共回覆的數量： 27
# 願意接受訪談人數： 14
# 不願意接受訪談人數： 13

# %%
###看看所有回覆者去當代藝術館次數分布和排序次數

# %%
####去當代藝術館次數分布

# %%
ALL_y=data['願意接受訪談']
sayyes=ALL_y['對當代藝術館的第一印象分數']
tempY5 = sayyes.get('5')
tempY5
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '咪',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間': '國立故宮博物院, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 世界宗教博物館、國立台灣科學教育館',
#   '看展的喜好方式': '走馬看花隨性看, 聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論',
#   '簡單與我們分享讓你印象深刻的博物館服務': '上次去了宗教博物館 平常對宗教的事不太會去觸碰 本身不信教 但因為朋友邀約就一起去了 我們是要去博物館內的特展 但由於外面的導覽員實在太熱情 就被拉去很多地方聽了很多關於宗教的解說 其實還蠻有趣的 裡面有各種宗教代表性的建築和物品、經文等等 在特展中也是沈浸式的體驗了生死輪迴 很有趣！是值得去嘗試的體驗！',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': [{}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': 'Stacy',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間': '臺北當代藝術館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 獨自參觀',
#   '簡單與我們分享讓你印象深刻的博物館服務': '無',
#   '您過去參觀「台北當代藝術館」的次數': 4,
#   '滿意度': [{'[導覽服務]': 4, '[館內標示]': 4, '[空間規劃]': 4, '[顧客服務]': 4, '[周邊景點]': 4}]}]

# %%
timesY5 = []
for a in tempY5:
    timesY5.append(a.get('您過去參觀「台北當代藝術館」的次數'))
print(timesY5)
# Out:
# [0, 4]

# %%
tempY4 = sayyes.get('4')
timesY4 = []
for b in tempY4:
    timesY4.append(b.get('您過去參觀「台北當代藝術館」的次數'))
print(timesY4)
# Out:
# [1, 3, 4, 3, 1, 2]

# %%
tempY3 = sayyes.get('3')
timesY3 = []
for c in tempY3:
    timesY3.append(c.get('您過去參觀「台北當代藝術館」的次數'))
print(timesY3)
# Out:
# [0, 0, 2, 0]

# %%
tempY2 = sayyes.get('2')
timesY2 = []
for d in tempY2:
    timesY2.append(d.get('您過去參觀「台北當代藝術館」的次數'))
print(timesY2)
# Out:
# [3, 2]

# %%
tempY1 = sayyes.get('1')
timesY1 = []
for e in tempY1:
    timesY1.append(e.get('您過去參觀「台北當代藝術館」的次數'))
print(timesY1)
# Out:
# []

# %%
ALL_n=data['不願意接受訪談']
sayno=ALL_n['對當代藝術館的第一印象分數']
tempN5 = sayno.get('5')
tempN5
# Out:
# [{'性別': '生理男',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '李冠煒',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國父紀念館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 參加館內活動, 獨自參觀',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []}]

# %%
timesN5 = []
for f in tempN5:
    timesN5.append(f.get('您過去參觀「台北當代藝術館」的次數'))
print(timesN5)
# Out:
# [0]

# %%
tempN4 = sayno.get('4')
timesN4 = []
for g in tempN4:
    timesN4.append(g.get('您過去參觀「台北當代藝術館」的次數'))
print(timesN4)
# Out:
# [2, 0, 6, 1, 3, 3]

# %%
tempN3 = sayno.get('3')
timesN3 = []
for h in tempN3:
    timesN3.append(h.get('您過去參觀「台北當代藝術館」的次數'))
print(timesN3)
# Out:
# [2, 0, 3, 0, 0, 1]

# %%
tempN2 = sayno.get('2')
timesN2 = []
for i in tempN2:
    timesN2.append(i.get('您過去參觀「台北當代藝術館」的次數'))
print(timesN2)
# Out:
# []

# %%
tempN1 = sayno.get('1')
timesN1 = []
for j in tempN1:
    timesN1.append(j.get('您過去參觀「台北當代藝術館」的次數'))
print(timesN1)
# Out:
# []

# %%
TIMES=timesN1+timesN2+timesN3+timesN4+timesN5+timesY1+timesY2+timesY3+timesY4+timesY5
TIMES
# Out:
# [2,
#  0,
#  3,
#  0,
#  0,
#  1,
#  2,
#  0,
#  6,
#  1,
#  3,
#  3,
#  0,
#  3,
#  2,
#  0,
#  0,
#  2,
#  0,
#  1,
#  3,
#  4,
#  3,
#  1,
#  2,
#  0,
#  4]

# %%
#統計大家去的次數
CC = {}
for key in TIMES:
  CC[key] = CC.get(key, 0) + 1
print (CC)
# Out:
# {2: 5, 0: 9, 3: 6, 1: 4, 6: 1, 4: 2}

# %%
####排序次數

# %%
# 使用dict去重，維持原來順序
TIMES0=list(dict.fromkeys(TIMES))
TIMES0
# Out:
# [2, 0, 3, 1, 6, 4]

# %%
# 排序所有回覆者排序去當代藝術館的次數
TIMES0.sort()
print(TIMES0)
# Out:
# [0, 1, 2, 3, 4, 6]

# %%
###一起來尋找我們最最最理想訪談者吧

# %%
####尋找有意願接受訪談的受訪者

# %%
YY=data['願意接受訪談']
print(YY)
# Out:
# {'對當代藝術館的第一印象分數': {'1': [], '2': [{'性別': '生理女', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '陳玉書🍿️', '最近2年參觀博物館的頻率': '每半年3次以內', '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 嘉義文化創意產業園區, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 樹火紀念紙博物館', '看展的喜好方式（可複選）': '租借導覽機, 聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 一定要打卡, 參加館內活動', '簡單與我們分享讓你印象深刻的博物館服務': '用linebot 做成的語音導覽服務', '您過去參觀「台北當代藝術館」的次數': 3, '滿意度': [{'[導覽服務]': 5, '[館內標示]': 4, '[空間規劃]': 3, '[顧客服務]': 3, '[周邊景點]': 4, '簡單與我們分享對 「台北當代藝術館」印象深刻的體驗': '展場內有很多互動裝置，可以跟觀者產生較大的連結'}]}, {'性別': '生理女', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '陳姿伶', '最近2年參觀博物館的頻率': '每半年3次以內', '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '租借導覽機, 走馬看花隨性看, 會跟著排隊參與體驗, 聽導覽員解說, 和朋友邊看邊討論, 一定要拍照, 一定要打卡, 購買紀念品, 一定會蓋紀念章, 參加館內活動, 獨自參觀', '簡單與我們分享讓你印象深刻的博物館服務': '拍貼機 互動裝置 漂亮的光', '您過去參觀「台北當代藝術館」的次數': 2, '滿意度': [{'[導覽服務]': 4, '[館內標示]': 2, '[空間規劃]': 2, '[顧客服務]': 2, '[周邊景點]': 4, '簡單與我們分享對 「台北當代藝術館」印象深刻的體驗': '動線不佳 場地昏暗 一進場就要去禮品店 展品自己
# ...

# %%
####尋找對當代藝術館整體好感度為3以下的表單回覆

# %%
YYY=YY['對當代藝術館的第一印象分數']
Y3=YYY['3']
Y2=YYY['2']
Y1=YYY['1']
print("對當代藝術館的第一印象分數3以下(含3):",Y3,Y2,Y1)
# Out:
# 對當代藝術館的第一印象分數3以下(含3): [{'性別': '生理女', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '🐯', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看', '簡單與我們分享讓你印象深刻的博物館服務': '高中畢業旅行去故宮南院，裡面展示的文物很多 導覽講的很仔細，各種擺飾也很漂亮。', '您過去參觀「台北當代藝術館」的次數': 0, '滿意度': []}, {'性別': '生理男', '年齡': '18歲以下', '族群': '未婚，學生身份', '姓名': '萊恩', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）': '台中科博館…？', '看展的喜好方式（可複選）': '走馬看花隨性看, 一定要拍照', '您過去參觀「台北當代藝術館」的次數': 0, '滿意度': []}, {'性別': '生理女', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '蘇文慈', '最近2年參觀博物館的頻率': '每個月1-3次', '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照', '您過去參觀「台北當代藝術館」的次數': 2, '滿意度': [{'[導覽服務]': 2, '[館內標示]': 2, '[空間規劃]': 3, '[顧客服務]': 3, '[周邊景點]': 4}]}, {'性別': '生理女', '年齡': '19-25歲', '族群': '未婚，學生身份', '姓名': '黃千華', '最近2年參觀博物館的頻率': '每半年3次以內', '曾經去過的大型展演空間（可複選）': '奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 國立台灣美術館, 中正紀念堂, 臺北市立
# ...

# %%
temp3 = YYY.get('3')
temp3
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '🐯',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '走馬看花隨性看',
#   '簡單與我們分享讓你印象深刻的博物館服務': '高中畢業旅行去故宮南院，裡面展示的文物很多 導覽講的很仔細，各種擺飾也很漂亮。',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []},
#  {'性別': '生理男',
#   '年齡': '18歲以下',
#   '族群': '未婚，學生身份',
#   '姓名': '萊恩',
#   '最近2年參觀博物館的頻率': '每年3次以內',
#   '曾經去過的大型展演空間（可複選）': '台中科博館…？',
#   '看展的喜好方式（可複選）': '走馬看花隨性看, 一定要拍照',
#   '您過去參觀「台北當代藝術館」的次數': 0,
#   '滿意度': []},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '蘇文慈',
#   '最近2年參觀博物館的頻率': '每個月1-3次',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 國立故宮博物院, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照',
#   '您過去參觀「台北當代藝術館」的次數': 2,
#   '滿意度': [{'[導覽服務]': 2, '[館內標示]': 2, '[空間規劃]': 3, '[顧客服務]': 3, '[周邊景點]': 4}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '黃千華',
# ...

# %%
times3 = []
for y in temp:
    times3.append(y.get('您過去參觀「台北當代藝術館」的次數'))
print(times3)
# Out:
# [0, 0, 2, 0]

# %%
temp2 = YYY.get('2')
temp2
# Out:
# [{'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '陳玉書🍿️',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國立故宮博物院南部院區, 奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 嘉義文化創意產業園區, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 樹火紀念紙博物館',
#   '看展的喜好方式（可複選）': '租借導覽機, 聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 一定要拍照, 一定要打卡, 參加館內活動',
#   '簡單與我們分享讓你印象深刻的博物館服務': '用linebot 做成的語音導覽服務',
#   '您過去參觀「台北當代藝術館」的次數': 3,
#   '滿意度': [{'[導覽服務]': 5,
#     '[館內標示]': 4,
#     '[空間規劃]': 3,
#     '[顧客服務]': 3,
#     '[周邊景點]': 4,
#     '簡單與我們分享對 「台北當代藝術館」印象深刻的體驗': '展場內有很多互動裝置，可以跟觀者產生較大的連結'}]},
#  {'性別': '生理女',
#   '年齡': '19-25歲',
#   '族群': '未婚，學生身份',
#   '姓名': '陳姿伶',
#   '最近2年參觀博物館的頻率': '每半年3次以內',
#   '曾經去過的大型展演空間（可複選）': '臺北當代藝術館, 國父紀念館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區',
#   '看展的喜好方式（可複選）': '租借導覽機, 走馬看花隨性看, 會跟著排隊參與體驗, 聽導覽員解說, 和朋友邊看邊討論, 一定要拍照, 一定要打卡, 購買紀念品, 一定會蓋紀念章, 參加館內活動, 獨自參觀',
#   '簡單與我們分享讓你印象深刻的博物館服務': '拍貼機 互動裝置 漂亮的光',
#   '您過去參觀「台北當代藝術館」的次數': 2,
#   '滿意度': [{'[導覽服務]': 4,
#     '[館內標示]': 2,
# ...

# %%
#for testing, 和上面程式碼無關不用理會
# Out:
# [0, 0, 2, 0, 0, 0, 2, 0]

# %%
times2 = []
for z in temp:
    times2.append(z.get('您過去參觀「台北當代藝術館」的次數'))
print(times2)
# Out:
# [0, 0, 2, 0]

# %%
temp1 = YYY.get('1')
temp1
# Out:
# []

# %%
type(Y3)
# Out:
# list

# %%
type(temp)
# Out:
# list

# %%
for y in YYY:
    if ask == y.get('姓名'):
        print(ask, '參觀次數是', y.get('您過去參觀「台北當代藝術館」的次數'), '次')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
#       1 for y in YYY:
# ----> 2     if ask == y.get('姓名'):
#       3         print(ask, '參觀次數是', y.get('您過去參觀「台北當代藝術館」的次數'), '次')
#
# NameError: name 'ask' is not defined

# %%
ask="黃千華"

# %%
Times_enumerate_sorted = sorted(Times_enumerate, key = lambda s: s[1], reverse = True)
Times_enumerate_sorted
# Out:
# [(4, 6), (5, 4), (2, 3), (0, 2), (3, 1), (1, 0)]
