# %%
import json
MuseumE=open('reply_for_museum_experience.json',encoding="UTF-8")

# %%
reply = json.load(MuseumE)
for n in reply.items():
    print(n)
# Out:
# ('表單回應 1', [{'性別': '生理女', '年齡': '19-25歲', '生活階段': '學生族群：未婚，學生身份', '姓名或稱呼': 'try', '最近2年參觀博物館的頻率': '每個月1-3次', '曾經去過的大型展演空間（可複選）\n': '臺北當代藝術館, 奇美博物館', '看展的喜好方式（可複選）': '走馬看花隨性看', '您過去參觀「台北當代藝術館」的次數': '2次以下', '對 「當代館」的整體印象好感度': 1, '滿意度 [導覽服務]': 3, '滿意度 [館內標示]': 3, '滿意度 [空間規劃]': 3, '滿意度 [顧客服務]': 3, '滿意度 [周邊景點]': 3, '請問您是否願意接受我們進一步的深度訪談（約一小時）': '否'}, {'性別': '生理男', '年齡': '19-25歲', '生活階段': '學生族群：未婚，學生身份', '姓名或稱呼': 'Suga', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）\n': '奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 和朋友邊看邊討論', '您過去參觀「台北當代藝術館」的次數': '都沒去過', '對 「當代館」的整體印象好感度': 3, '請問您是否願意接受我們進一步的深度訪談（約一小時）': '否'}, {'性別': '生理男', '年齡': '19-25歲', '生活階段': '學生族群：未婚，學生身份', '姓名或稱呼': '徐紀鵬', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）\n': '臺北當代藝術館, 奇美博物館, 國立故宮博物院, 國父紀念館, 國立台灣美術館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 和朋友邊看邊討論', '您過去參觀「台北當代藝術館」的次數': '2次以下', '對 「當代館」的整體印象好感度': 4, '滿意度 [導覽服務]': '5（非常滿意）', '滿意度 [館內標示]': '5（非常滿意）', '滿意度 [空間規劃]
# ...

# %%
#將網路上轉的json後的巢狀結構
replyforus = reply.get('表單回應 1')
print(replyforus)
# Out:
# [{'性別': '生理女', '年齡': '19-25歲', '生活階段': '學生族群：未婚，學生身份', '姓名或稱呼': 'try', '最近2年參觀博物館的頻率': '每個月1-3次', '曾經去過的大型展演空間（可複選）\n': '臺北當代藝術館, 奇美博物館', '看展的喜好方式（可複選）': '走馬看花隨性看', '您過去參觀「台北當代藝術館」的次數': '2次以下', '對 「當代館」的整體印象好感度': 1, '滿意度 [導覽服務]': 3, '滿意度 [館內標示]': 3, '滿意度 [空間規劃]': 3, '滿意度 [顧客服務]': 3, '滿意度 [周邊景點]': 3, '請問您是否願意接受我們進一步的深度訪談（約一小時）': '否'}, {'性別': '生理男', '年齡': '19-25歲', '生活階段': '學生族群：未婚，學生身份', '姓名或稱呼': 'Suga', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）\n': '奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 和朋友邊看邊討論', '您過去參觀「台北當代藝術館」的次數': '都沒去過', '對 「當代館」的整體印象好感度': 3, '請問您是否願意接受我們進一步的深度訪談（約一小時）': '否'}, {'性別': '生理男', '年齡': '19-25歲', '生活階段': '學生族群：未婚，學生身份', '姓名或稱呼': '徐紀鵬', '最近2年參觀博物館的頻率': '每年3次以內', '曾經去過的大型展演空間（可複選）\n': '臺北當代藝術館, 奇美博物館, 國立故宮博物院, 國父紀念館, 國立台灣美術館, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區', '看展的喜好方式（可複選）': '走馬看花隨性看, 和朋友邊看邊討論', '您過去參觀「台北當代藝術館」的次數': '2次以下', '對 「當代館」的整體印象好感度': 4, '滿意度 [導覽服務]': '5（非常滿意）', '滿意度 [館內標示]': '5（非常滿意）', '滿意度 [空間規劃]': 4, '滿意度 
# ...

# %%
#總共回覆數量
number=len(replyforus)
print(number)
# Out:
# 109

# %%
#尋找對當代藝術館整體好感度為3以下的表單回覆
no1=[]
no1_data = []
for i in replyforus:
    if i.get("對 「當代館」的整體印象好感度") <= 3:
        no1.append(i.get('對 「當代館」的整體印象好感度'))
        no1_data.append(i.values())
print(no1_data)
# Out:
# [dict_values(['生理女', '19-25歲', '學生族群：未婚，學生身份', 'try', '每個月1-3次', '臺北當代藝術館, 奇美博物館', '走馬看花隨性看', '2次以下', 1, 3, 3, 3, 3, 3, '否']), dict_values(['生理男', '19-25歲', '學生族群：未婚，學生身份', 'Suga', '每年3次以內', '奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 中正紀念堂, 松菸文創園區, 華山文化創意產業園區', '走馬看花隨性看, 和朋友邊看邊討論', '都沒去過', 3, '否']), dict_values(['生理女', '19-25歲', '學生族群：未婚，學生身份', '洪', '每半年3次以內', '奇美博物館, 松菸文創園區, 華山文化創意產業園區', '走馬看花隨性看, 自己閱讀手冊或說明牌', '都沒去過', 3, '否']), dict_values(['生理男', '19-25歲', '學生族群：未婚，學生身份', '林玟廷', '每年3次以內', '奇美博物館, 中正紀念堂', '走馬看花隨性看, 購買紀念品, 獨自參觀', '都沒去過', 3, '否']), dict_values(['生理女', '19-25歲', '學生族群：未婚，學生身份', '安ㄅ', '每個月1-3次', '臺北當代藝術館, 奇美博物館, 國立故宮博物院, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 羅浮宮, 梵谷博物館', '租借導覽機, 走馬看花隨性看, 聽導覽員解說, 自己閱讀手冊或說明牌, 和朋友邊看邊討論, 購買紀念品', '依照年齡打造不同導覽內容，如給小孩聽的導覽是由小王子口述導覽內容（荷蘭皇宮）', '2次以下', 3, 3, 4, 4, 4, 3, '否']), dict_values(['生理女', '19-25歲', '學生族群：未婚，學生身份', '媛媛小寶貝的朋友', '每半年3次以內', '國立故宮博物院南部院區, 奇美博物館, 國立臺灣歷史博物館, 國立故宮博物院, 國父紀念館, 國立台灣美術館, 嘉義文化創意產業園區, 中正紀念堂, 臺北市立美術館, 松菸文創園區, 華山文化創意產業園區, 高美館 台南美術館', '租借導覽
# ...

# %%
#尋找有意願接受訪談的受訪者
no2={}
for j in replyforus:
    if i.get("請問您是否願意接受我們進一步的深度訪談（約一小時）") == "是":0
         no1.append(i.get('表單回應 1'))
print(no1)

# %%
#取交集找到受訪者
